# %%
from dotenv import load_dotenv
load_dotenv(override=True)

from ingest import load_faq_data, build_index
from rag_helper import RAGBase
from openai import OpenAI
import os

# %%
documents = load_faq_data()
index = build_index(documents)

# %%
llm_client = OpenAI(
    base_url="https://openrouter.ai/api/v1",
    api_key=os.getenv("OPEN_ROUTER_API_KEY"),
)

assistant = RAGBase(
    index=index,
    llm_client=llm_client,
)

# %%
answer = assistant.rag("I just discovered the course. Can I join now?")
print(answer)
# Out:
# Yes, you can join right now. However, if you’d like to receive a certificate, you’ll need to submit your project while the course is still accepting submissions.

# %%
print(assistant.rag("How I get a certificate?"))
# Out:
# You canreceive a certificate only if you **complete the entire course within a live cohort** (i.e., you follow the instructor‑led schedule and participate in the live sessions).
#
# - Self‑paced progress does **not** qualify you for a certificate.
# - To earn the certificate you must also **pass the Capstone project**, which involves submitting a project that will be peer‑reviewed by three other learners (and you will review three peers as well).
# - The final grade is the median of the peer‑review scores, and meeting all peer‑review obligations is required to obtain the certificate.
#
# So, enroll in a live cohort, complete the coursework, submit a passing Capstone project, and fulfill the peer‑review requirements. That is how you get the certificate. If you only work in self‑paced mode, you will not receive a certificate.

# %%
print(assistant.rag("Can I still join if the course is already started?"))
# Out:
# Yes. You can still join thecourse even after it has started. You’re free to begin learning and working on the material at any time, but if you want to receive a certificate you must submit your project before the submission period closes. If a certificate isn’t your goal, you can participate in the course without meeting that deadline.
